# %%
# !pip3 install pandas
# Out:
# ...
#   Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# ...
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/pruthveshbaitule25/Downloads/COLLEGE - Sheet2.csv")

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0          8.0           149.0           67.0               3.0    26/01/2024
# 1          5.0           952.0          233.0               3.0    19/01/2024
# 2         72.0             NaN          472.0               1.0    01/01/2024
# 3        100.0           783.0          371.0               5.0    15/01/2024
# 4         34.0           853.0          318.0               1.0           NaN
# 5         97.0           109.0          281.0               5.0    26/01/2024
# 6         18.0           230.0            NaN               2.0    02/01/2024
# 7         66.0           148.0          462.0               5.0    02/01/2024
# 8         59.0           889.0          194.0               NaN    10/01/2024
# 9         64.0           840.0          500.0               4.0    01/01/2024
# 10        25.0           444.0          150.0               1.0    22/01/2024
# ...

# %%
x =pd.isnull(data[["Math_Score"]])

# %%
x
# Out:
#     Math_Score
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23        True
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False

# %%
data["Math_Score"] = data["Math_Score"].fillna(data["Math_Score"].mean())

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000           149.0           67.0               3.0    26/01/2024
# 1     5.000000           952.0          233.0               3.0    19/01/2024
# 2    72.000000             NaN          472.0               1.0    01/01/2024
# 3   100.000000           783.0          371.0               5.0    15/01/2024
# 4    34.000000           853.0          318.0               1.0           NaN
# 5    97.000000           109.0          281.0               5.0    26/01/2024
# 6    18.000000           230.0            NaN               2.0    02/01/2024
# 7    66.000000           148.0          462.0               5.0    02/01/2024
# 8    59.000000           889.0          194.0               NaN    10/01/2024
# 9    64.000000           840.0          500.0               4.0    01/01/2024
# 10   25.000000           444.0          150.0               1.0    22/01/2024
# ...

# %%
data["Math_Score"] = data["Math_Score"].fillna(data["Math_Score"].median())

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000           149.0           67.0               3.0    26/01/2024
# 1     5.000000           952.0          233.0               3.0    19/01/2024
# 2    72.000000             NaN          472.0               1.0    01/01/2024
# 3   100.000000           783.0          371.0               5.0    15/01/2024
# 4    34.000000           853.0          318.0               1.0           NaN
# 5    97.000000           109.0          281.0               5.0    26/01/2024
# 6    18.000000           230.0            NaN               2.0    02/01/2024
# 7    66.000000           148.0          462.0               5.0    02/01/2024
# 8    59.000000           889.0          194.0               NaN    10/01/2024
# 9    64.000000           840.0          500.0               4.0    01/01/2024
# 10   25.000000           444.0          150.0               1.0    22/01/2024
# ...

# %%
data["Math_Score"] = data["Math_Score"].fillna(data["Math_Score"].std())

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000           149.0           67.0               3.0    26/01/2024
# 1     5.000000           952.0          233.0               3.0    19/01/2024
# 2    72.000000             NaN          472.0               1.0    01/01/2024
# 3   100.000000           783.0          371.0               5.0    15/01/2024
# 4    34.000000           853.0          318.0               1.0           NaN
# 5    97.000000           109.0          281.0               5.0    26/01/2024
# 6    18.000000           230.0            NaN               2.0    02/01/2024
# 7    66.000000           148.0          462.0               5.0    02/01/2024
# 8    59.000000           889.0          194.0               NaN    10/01/2024
# 9    64.000000           840.0          500.0               4.0    01/01/2024
# 10   25.000000           444.0          150.0               1.0    22/01/2024
# ...

# %%
data["Math_Score"] = data["Math_Score"].fillna(data["Math_Score"].min())

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000           149.0           67.0               3.0    26/01/2024
# 1     5.000000           952.0          233.0               3.0    19/01/2024
# 2    72.000000             NaN          472.0               1.0    01/01/2024
# 3   100.000000           783.0          371.0               5.0    15/01/2024
# 4    34.000000           853.0          318.0               1.0           NaN
# 5    97.000000           109.0          281.0               5.0    26/01/2024
# 6    18.000000           230.0            NaN               2.0    02/01/2024
# 7    66.000000           148.0          462.0               5.0    02/01/2024
# 8    59.000000           889.0          194.0               NaN    10/01/2024
# 9    64.000000           840.0          500.0               4.0    01/01/2024
# 10   25.000000           444.0          150.0               1.0    22/01/2024
# ...

# %%
data["Writing_score"] = data["Writing_score"].fillna(data["Writing_score"].mean())

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000           149.0      67.000000               3.0    26/01/2024
# 1     5.000000           952.0     233.000000               3.0    19/01/2024
# 2    72.000000             NaN     472.000000               1.0    01/01/2024
# 3   100.000000           783.0     371.000000               5.0    15/01/2024
# 4    34.000000           853.0     318.000000               1.0           NaN
# 5    97.000000           109.0     281.000000               5.0    26/01/2024
# 6    18.000000           230.0     263.928571               2.0    02/01/2024
# 7    66.000000           148.0     462.000000               5.0    02/01/2024
# 8    59.000000           889.0     194.000000               NaN    10/01/2024
# 9    64.000000           840.0     500.000000               4.0    01/01/2024
# 10   25.000000           444.0     150.000000               1.0    22/01/2024
# ...

# %%
data["Reading_score "] = data["Reading_score "].fillna(data["Reading_score "].mean())

# %%
data
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000      149.000000      67.000000               3.0    26/01/2024
# 1     5.000000      952.000000     233.000000               3.0    19/01/2024
# 2    72.000000      510.821429     472.000000               1.0    01/01/2024
# 3   100.000000      783.000000     371.000000               5.0    15/01/2024
# 4    34.000000      853.000000     318.000000               1.0           NaN
# 5    97.000000      109.000000     281.000000               5.0    26/01/2024
# 6    18.000000      230.000000     263.928571               2.0    02/01/2024
# 7    66.000000      148.000000     462.000000               5.0    02/01/2024
# 8    59.000000      889.000000     194.000000               NaN    10/01/2024
# 9    64.000000      840.000000     500.000000               4.0    01/01/2024
# 10   25.000000      444.000000     150.000000               1.0    22/01/2024
# ...

# %%
df = data

# %%
df.dropna(how='all')
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000      149.000000      67.000000               3.0    26/01/2024
# 1     5.000000      952.000000     233.000000               3.0    19/01/2024
# 2    72.000000      510.821429     472.000000               1.0    01/01/2024
# 3   100.000000      783.000000     371.000000               5.0    15/01/2024
# 4    34.000000      853.000000     318.000000               1.0           NaN
# 5    97.000000      109.000000     281.000000               5.0    26/01/2024
# 6    18.000000      230.000000     263.928571               2.0    02/01/2024
# 7    66.000000      148.000000     462.000000               5.0    02/01/2024
# 8    59.000000      889.000000     194.000000               NaN    10/01/2024
# 9    64.000000      840.000000     500.000000               4.0    01/01/2024
# 10   25.000000      444.000000     150.000000               1.0    22/01/2024
# ...

# %%
df.dropna(axis=1,inplace=False)
# Out:
#     Math_Score  Reading_score   Writing_score
# 0     8.000000      149.000000      67.000000
# 1     5.000000      952.000000     233.000000
# 2    72.000000      510.821429     472.000000
# 3   100.000000      783.000000     371.000000
# 4    34.000000      853.000000     318.000000
# 5    97.000000      109.000000     281.000000
# 6    18.000000      230.000000     263.928571
# 7    66.000000      148.000000     462.000000
# 8    59.000000      889.000000     194.000000
# 9    64.000000      840.000000     500.000000
# 10   25.000000      444.000000     150.000000
# 11   52.000000      362.000000     290.000000
# 12   70.000000      426.000000     387.000000
# 13   51.000000      694.000000     234.000000
# 14   17.000000      510.821429     404.000000
# 15   70.000000      870.000000      76.000000
# 16   10.000000      808.000000      67.000000
# 17   34.000000      207.000000       6.000000
# 18   35.000000      158.000000     288.000000
# ...

# %%
df
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000      149.000000      67.000000               3.0    26/01/2024
# 1     5.000000      952.000000     233.000000               3.0    19/01/2024
# 2    72.000000      510.821429     472.000000               1.0    01/01/2024
# 3   100.000000      783.000000     371.000000               5.0    15/01/2024
# 4    34.000000      853.000000     318.000000               1.0           NaN
# 5    97.000000      109.000000     281.000000               5.0    26/01/2024
# 6    18.000000      230.000000     263.928571               2.0    02/01/2024
# 7    66.000000      148.000000     462.000000               5.0    02/01/2024
# 8    59.000000      889.000000     194.000000               NaN    10/01/2024
# 9    64.000000      840.000000     500.000000               4.0    01/01/2024
# 10   25.000000      444.000000     150.000000               1.0    22/01/2024
# ...

# %%
#row atleast with one null will be deleted 
df.dropna(axis=0 , how='any')
# Out:
#     Math_Score  Reading_score   Writing_score  Placement_Offfer Clg_Join_date  \
# 0     8.000000      149.000000      67.000000               3.0    26/01/2024
# 1     5.000000      952.000000     233.000000               3.0    19/01/2024
# 2    72.000000      510.821429     472.000000               1.0    01/01/2024
# 3   100.000000      783.000000     371.000000               5.0    15/01/2024
# 5    97.000000      109.000000     281.000000               5.0    26/01/2024
# 6    18.000000      230.000000     263.928571               2.0    02/01/2024
# 7    66.000000      148.000000     462.000000               5.0    02/01/2024
# 9    64.000000      840.000000     500.000000               4.0    01/01/2024
# 11   52.000000      362.000000     290.000000               4.0    21/01/2024
# 12   70.000000      426.000000     387.000000               3.0    09/01/2024
# 13   51.000000      694.000000     234.000000               1.0    09/01/2024
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.boxplot(by="Math_Score" , column = ["Math_Score"])
# Out:
# <Axes: title={'center': 'Math_Score'}, xlabel='Math_Score'>

# %%
df.boxplot('Math_Score')
# Out:
# <Axes: >

# %%
import numpy as np 
print(np.where(df["Math_Score"]>60))
# Out:
# (array([ 2,  3,  5,  7,  9, 12, 15, 21, 27]),)
